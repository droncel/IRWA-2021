# %% [markdown]
# # Information Retrieval and Web Analytics Project
# ## Ranking

# %% [markdown]
# #### Packages
#
# We first import all the packages that we need for text processing:

# %%
import time
import string
from array import array
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
import json
import nltk
import demoji
import re
nltk.download('stopwords');
from deep_translator import GoogleTranslator
from gensim.models.word2vec import Word2Vec
from numpy import linalg as LA

from collections import defaultdict
import math
import numpy as np
import collections
from numpy import linalg as la
import matplotlib.cm as cm
import random
import pandas as pd
import matplotlib.pyplot as plt
import dateutil.parser
import datetime
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\danie\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# C:\Users\danie\AppData\Local\Continuum\anaconda3\lib\site-packages\gensim\similarities\__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %% [markdown]
# ## Load data

# %% [markdown]
# **Read the file with the tweets:**

# %%
docs_path = 'dataset_tweets_WHO.txt'

# Read the JSON file in a unique string
with open(docs_path) as fp:
    corpus = fp.readlines()[0]

# Load the JSON file as a dictionary
corpus = json.loads(corpus)

# %%
print("There are \033[1m%i tweets\033[0m in the dataset" %len(corpus))
# Out:
# There are 2399 tweets in the dataset

# %% [markdown]
# ## Text Processing

# %% [markdown]
# ### Functions

# %%
def italics_to_plaintext(text):
    #difference between an italic lowecase character and its corresponding plaintext lowercase character
    diff_lower = ord('𝘢') - ord('a')
    #difference between an italic uppercase character and its corresponding plaintext uppercase character
    diff_upper = ord('𝘈') - ord('A')
    
    plaintext = ""
    for c in text:
        # if the character is italic lowercase, get the corresponding plaintext lowercase character
        if ord(c) >= ord('𝘢') and ord(c) <= ord('𝘻'):
            plaintext += chr(ord(c) - diff_lower)
        # else if the character is italic uppercase, get the corresponding plaintext uppercase character
        elif ord(c) >= ord('𝘈') and  ord(c) <= ord('𝘡'):
            plaintext += chr(ord(c) - diff_upper)
        else:
            plaintext += c
    
    return plaintext

def bold_to_plaintext(text):
    #difference between a bold lowecase character and its corresponding plaintext lowercase character
    diff_lower = ord('𝐚') - ord('a')
    #difference between a bold uppercase character and its corresponding plaintext uppercase character
    diff_upper = ord('𝐀') - ord('A')
    
    plaintext = ""
    for c in text:
        # if the character is bold lowercase, get the corresponding plaintext lowercase character
        if ord(c) >= ord('𝐚') and ord(c) <= ord('𝐳'):
            plaintext += chr(ord(c) - diff_lower)
        # else if the character is bold uppercase, get the corresponding plaintext uppercase character
        elif ord(c) >= ord('𝐀') and  ord(c) <= ord('𝐙'):
            plaintext += chr(ord(c) - diff_upper)
        else:
            plaintext += c
    
    return plaintext

def getTerms(text, stemming, stops):
    # Text to lowercase
    text = text.lower()
    # Text delete italic letter type if needed
    text = italics_to_plaintext(text)
    # Text delete bold letter type if needed
    text = bold_to_plaintext(text)
    # Delete all urls
    text = re.sub(r'http\S+', ' ', text) 
    # Delete all non-alphanumerical characters (it includes emojis) except '#' and '@'
    text = re.sub(r'[^A-Za-z0-9#@]+', ' ', text)
    # Text tokenization
    words = text.split()
    # Remove stopwords
    words = [word for word in words if word not in stops]
    # Get the stem of each word
    words = [stemming.stem(word) for word in words]
    
    return words

# %% [markdown]
# ### Process tweets

# %%
stemming = PorterStemmer()
# Delete also "amp" (&) and "rt"
stops = set(stopwords.words("english")).union(set({'amp', 'rt'}))

# Dictionary where we'll save all the processed tweets
data = {}
for tweet in corpus:
    
    #In case that the tweet is not in english, we traduce it
    lang = corpus[tweet]['lang']
    if lang != 'en':
        text_tweet = GoogleTranslator(target='en').translate(corpus[tweet]['full_text'])
    else:
        text_tweet = corpus[tweet]['full_text']
    
    # Get the text tokenized and cleaned 
    text_tweet_processed = getTerms(text_tweet, stemming, stops)
    
    if text_tweet_processed != []: #In case that the text is not null                       
        data[tweet] = {}
        data[tweet]['org_text'] = text_tweet
        data[tweet]['text'] = text_tweet_processed
        
        if 'retweeted_status' in corpus[tweet]:
            # Save the original tweet's user
            data[tweet]['user'] = corpus[tweet]['retweeted_status']['user']['name']
            # Save the original tweet's url
            try:
                data[tweet]['url'] = corpus[tweet]['retweeted_status']['entities']['media'][0]['url']
            except: 
                data[tweet]['url'] = ''
        else:
            data[tweet]['user'] = corpus[tweet]['user']['name']
            try:
                data[tweet]['url'] = corpus[tweet]['entities']['media'][0]['url']
            except: 
                data[tweet]['url'] = ''

        # Save all emojis used with its meaning
        data[tweet]['emojis'] = demoji.findall(corpus[tweet]['full_text'])

        # Save creation data
        data[tweet]['date'] = corpus[tweet]['created_at']

        # Save the number of retweets of this tweet
        data[tweet]['retweets'] = corpus[tweet]['retweet_count']

        # Save the number of 'favorites' of this tweet
        data[tweet]['favorites'] = corpus[tweet]['favorite_count']
        
        # Save the hashtags of this tweet
        hashtags = []
        for i in corpus[tweet]['entities']['hashtags']:
            hashtags.append(i['text'])
            data[tweet]['text'].append(i['text'].lower())
    
        data[tweet]['hashtags'] = hashtags

        # Save the full name of all the users mentioned
        data[tweet]['user_mentions'] = list()
        ## List of dictionaries, each with information of a user mentioned
        users_data = corpus[tweet]['entities']['user_mentions']
        for user in users_data:
            data[tweet]['user_mentions'].append(user['name'])

# %% [markdown]
# ## Indexing

# %% [markdown]
# ### Functions

# %%
def create_index_tfidf(data, num_d):
    """
    Implement the inverted index and compute tf, df and idf
    
    Input:
    * lines: collection of Wikipedia articles
    * num_d: total number of documents
    
    Returns:
    * index: the inverted index (implemented through a python dictionary) containing terms as keys and the corresponding 
    * list of document these keys appears in (and the positions) as values
    * tf: normalized term frequency for each term in each document
    * df: number of documents each term appear in
    * idf: inverse document frequency of each term
    """
        
    index = defaultdict(list)
    tf = defaultdict(list) #term frequencies of terms in documents (documents in the same order as in the main index)
    df = defaultdict(int) #document frequencies of terms in the corpus
    idf = defaultdict(float)
    
    for tweet_id in data:   
        terms = data[tweet_id]['text']      

        termdictTweet = {}

        for position, term in enumerate(terms): # Tweet's terms
            try:
                # If the term is already in the dict append the position to the corrisponding list
                termdictTweet[term][1].append(position) 
            except:
                # Add the new term as dict key and initialize the array of positions and add the position
                termdictTweet[term] = [tweet_id, array('I',[position])] 
        
        # Normalize term frequencies
        norm = 0
        for term, posting in termdictTweet.items(): 
            norm += len(posting[1])**2
        norm = math.sqrt(norm)


        # Calculate the tf and df weights
        for term, posting in termdictTweet.items():     
            # Append the tf
            tf[term].append(np.round(len(posting[1])/norm,4))
            # Increment the document frequency of current term
            df[term] += len(posting)
        
        # Merge the current tweet index with the main index
        for termtweet, postingtweet in termdictTweet.items():
            index[termtweet].append(postingtweet)
            
        # Compute idf
        for term in df:
            idf[term] = np.round(np.log(float(num_d/df[term])),4)
            
    return index, tf, df, idf

# %% [markdown]
# ### Create the index

# %%
start_time = time.time()
num_d = len(data)
index, tf, df, idf = create_index_tfidf(data, num_d)
print("Total time to create the index: {} seconds" .format(np.round(time.time() - start_time,2)))
# Out:
# Total time to create the index: 128.04 seconds

# %% [markdown]
# ### Selected queries

# %%
q = ["#COVID19",
     "covid vaccine",
     "global pandemic",
     "#mentalhealth",
     "death risk"]

# %% [markdown]
# ## Ranking

# %% [markdown]
# ### TF-IDF + Cosine Similarity

# %% [markdown]
# #### Implementation

# %%
def rankTweets(terms, tweets, index, idf, tf):
    """
    Perform the ranking of the results of a search based on the tf-idf weights
    
    Argument:
    * terms: list of query terms
    * docs: list of documents, to rank, matching the query
    * index: inverted index data structure
    * idf: inverted document frequencies
    * tf: term frequencies
    * titleIndex: mapping between page id and page title
    
    Returns:
    Print the list of ranked documents
    """
        
    tweetVectors = defaultdict(lambda: [0]*len(terms))
    queryVector = [0]*len(terms)    

    # Compute the norm for the query tf
    query_terms_count = collections.Counter(terms) # get the frequency of each term in the query 
    query_norm = la.norm(list(query_terms_count.values()))
    
    for termIndex, term in enumerate(terms): #termIndex is the index of the term in the query
        if term not in index:
            continue
                    
        ## Compute tf*idf normalized
        queryVector[termIndex] = (query_terms_count[term] / query_norm) * idf[term]

        # Generate tweetVectors for matching docs
        for tweetIndex, (tweet, postings) in enumerate(index[term]):
            if tweet in tweets:
                tweetVectors[tweet][termIndex] = tf[term][tweetIndex]

    # Score of each tweet
    tweetScores = [ [np.dot(curTweetVec, queryVector), tweet] for tweet, curTweetVec in tweetVectors.items() ]
    tweetScores.sort(reverse=True)
    scores = [x[0] for x in tweetScores]
    resultTweets = [x[1] for x in tweetScores]
    #print document titles instead if document id's
    #resultDocs=[ titleIndex[x] for x in resultDocs ]
    if len(resultTweets) == 0:
        print("No results found, try again")
        query = input()
        tweets = search_tf_idf(query, index)    
    #print ('\n'.join(resultDocs), '\n')
    return resultTweets, scores

# %%
def search_tf_idf(query, index):
    stemming = PorterStemmer()
    stops = set(stopwords.words("english")).union(set({'amp', 'rt'}))
    
    query = getTerms(query, stemming, stops)
    tweets = set()

    for i, term in enumerate(query):
        try:
            # store in termDocs the ids of the docs that contain "term"                        
            termDocs = [posting[0] for posting in index[term]]
            
            # if this is the first word of the query, save all the tweets with this word
            if i == 0:
                tweets = tweets.union(termDocs)
            # for the next words, only keey those that contain that word and all the past words of the query
            else:
                tweets = tweets.intersection(termDocs)
        except:
            #term is not in index
            pass
    
    tweets = list(tweets)
    ranked_tweets, scores = rankTweets(query, tweets, index, idf, tf)   
    return ranked_tweets, scores

# %% [markdown]
# #### Testing the retrieval system

# %%
print("\033[1mInsert a query:\033[0m\n")
query = input()
ranked_tweets, scores = search_tf_idf(query, index)    
top = 5

print("\n======================\n\033[1mTop {} results out of {} for the searched query:\033[0m\n".format(top, len(ranked_tweets)))
for d_id in ranked_tweets[:top]:
    print("\n\033[1mTweet id = {}\033[0m".format(d_id))
    print("   - Tweet_text = {} ".format(data[d_id]['org_text']))
    print("   - Tweet_user = {} ".format(data[d_id]['user']))
    print("   - Tweet_date = {} ".format(data[d_id]['date']))
    print("   - Tweet_hashtags = {} ".format(data[d_id]['hashtags']))
    print("   - Tweet_likes = {} ".format(data[d_id]['favorites']))
    print("   - Tweet_retweets = {} ".format(data[d_id]['retweets']))
    print("   - Tweet_url = {} ".format(data[d_id]['url']))
# Out:
# Insert a query:
#
# covid vaccine
#
# ======================
# Top 5 results out of 15 for the searched query:
#
#
# Tweet id = 1959
#    - Tweet_text = 💉💉💉💉
# 💉💉💉💉
# 💉💉💉💉
# 💉💉💉💉
# 💉💉💉💉                 💉💉💉💉
# 💉💉💉💉                 💉💉💉💉
#
# COVID-19 vaccines     COVID-19 vaccines
# in 10 countries             in the rest of the 🌍
#
# #VaccinEquity is 🗝️ to ending the pandemic, together!
#
# #WorldEmojiDay
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Sat Jul 17 16:24:23 +0000 2021
#    - Tweet_hashtags = ['VaccinEquity', 'WorldEmojiDay']
#    - Tweet_likes = 3486
#    - Tweet_retweets = 1517
#    - Tweet_url =
#
# Tweet id = 2257
#    - Tweet_text = Q&amp;A #AskWHO on COVID-19 vaccines effectiveness https://t.co/FEdfOREhjn
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Wed Jun 30 16:12:43 +0000 2021
#    - Tweet_hashtags = ['AskWHO']
#    - Tweet_likes = 219
#    - Tweet_retweets = 85
#    - Tweet_url =
#
# Tweet id = 904
#    - Tweet_text = #COVID19 variants &amp; vaccines:
#
# ✅ COVID-19 vaccines provide strong protection against serious illness &amp; death
# ✅ Get all necessary doses to develop maximum protection
# ✅ Continue practicing all the protective behaviours even after vaccination to stop COVID-19 variants
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Mon Sep 06 08:09:59 +0000 2021
#    - Tweet_hashtags = ['COVID19']
#    - Tweet_likes = 352
#    - Tweet_retweets = 169
#    - Tweet_url =
#
# Tweet id = 4
#    - Tweet_text = RT @opsoms: If you are fully vaccinated 💉💉, can you still get COVID-19?
#
# 🚨 It does not matter if you are vaccinated or if you are still waiting, yes ...
#    - Tweet_user = OPS/OMS
#    - Tweet_date = Wed Oct 13 05:47:10 +0000 2021
#    - Tweet_hashtags = []
#    - Tweet_likes = 0
#    - Tweet_retweets = 43
#    - Tweet_url = https://t.co/YxWlXt1QWr
#
# Tweet id = 61
#    - Tweet_text = RT @WHOPhilippines: Vaccines can’t stop #COVID19 alone, but by doing it all we can help protect ourselves and our loved ones against COVID-…
#    - Tweet_user = World Health Organization Philippines
#    - Tweet_date = Mon Oct 11 04:39:10 +0000 2021
#    - Tweet_hashtags = ['COVID19']
#    - Tweet_likes = 0
#    - Tweet_retweets = 71
#    - Tweet_url = https://t.co/jTw5stAksU

# %% [markdown]
# ## Your score + cosine similarity

# %% [markdown]
# Our score, SBDM, conists on taking into account the metadata from each teweet to rank them given a query.

# %% [markdown]
# #### Implementation

# %%
def tweets_population(data, df):
    
    fav_mean = defaultdict()
    rtw_mean = defaultdict()
    
    for tw_id in data:
        for word in data[tw_id]['text']:
            if word not in fav_mean: 
                fav_mean[word] = data[tw_id]['favorites']
                rtw_mean[word] = data[tw_id]['retweets']
            else:
                fav_mean[word] += data[tw_id]['favorites']
                rtw_mean[word] += data[tw_id]['retweets']
                
    for word in fav_mean:
        fav_mean[word] = fav_mean[word] / df[word]
        rtw_mean[word] = rtw_mean[word] / df[word]
    
    return fav_mean, rtw_mean

# %%
def compute_diff_date(date):
    return (datetime.datetime.now().replace(tzinfo=None) - date.replace(tzinfo=None)).days

# %%
def rankTweets_sbdm(terms, tweets, index, idf, tf, fav_mean, rtw_mean, fav_rate, rtw_rate, date_rate):
    
    #Initialize the dictionaries with the tweets' vectors
    tweetVectors_terms = defaultdict(lambda: [0]*len(terms))
    tweetVectors_fav = defaultdict(lambda: [0]*len(terms))
    tweetVectors_rtw = defaultdict(lambda: [0]*len(terms))
    tweetVectors = defaultdict(lambda: [0]*len(terms))
    
    #Initialize the query vector
    queryVector_terms, queryVector_fav, queryVector_rtw = [0]*len(terms), [0]*len(terms), [0]*len(terms)

    # Compute the norm for the query TF
    query_terms_count = collections.Counter(terms) # get the frequency of each term in the query 
    query_norm = la.norm(list(query_terms_count.values()))
    
    #Get TF-IDF vectors
    for termIndex, term in enumerate(terms): #termIndex is the index of the term in the query
        if term not in index:
            continue
                    
        ## Compute tf*idf normalized
        queryVector_terms[termIndex] = (query_terms_count[term] / query_norm) * idf[term]

        # Generate tweetVectors for matching docs
        for tweetIndex, (tweet, postings) in enumerate(index[term]):
            if tweet in tweets:
                tweetVectors_terms[tweet][termIndex] = tf[term][tweetIndex]
    
    #Get population vectors
    for termIndex, term in enumerate(terms): 
        if term not in index:
            continue
                    
        queryVector_fav[termIndex] = fav_mean[term]
        queryVector_rtw[termIndex] = rtw_mean[term]

        for tweetIndex, (tweet, postings) in enumerate(index[term]):
            if tweet in tweets:
                tweetVectors_fav[tweet][termIndex] = fav_mean[term]
                tweetVectors_rtw[tweet][termIndex] = rtw_mean[term]
    
    
    #We normalize the population vectors
    queryVector_fav = queryVector_fav / la.norm(queryVector_fav)
    queryVector_rtw = queryVector_rtw / la.norm(queryVector_rtw)
    
    for tweet in tweetVectors_fav:
        tweetVectors_fav[tweet] = tweetVectors_fav[tweet] / la.norm(tweetVectors_fav[tweet])
        tweetVectors_rtw[tweet] = tweetVectors_rtw[tweet] / la.norm(tweetVectors_rtw[tweet])    
    
    #Final tweets and query vectors
    for tweet, curTweetVec in tweetVectors_terms.items():
        tweetVectors[tweet] = curTweetVec + rtw_rate*tweetVectors_rtw[tweet] + fav_rate*tweetVectors_fav[tweet]
        tweet_date = dateutil.parser.parse(data[tweet]['date'])
        date_diff = compute_diff_date(tweet_date)
        tweetVectors[tweet] = np.append(tweetVectors[tweet], 1/(date_diff*date_rate))
    
    queryVector = queryVector_terms + rtw_rate*queryVector_rtw + fav_rate*queryVector_fav
    queryVector = np.append(queryVector, 1/date_rate)
    
    #We compute cosine similarity
    tweetScores = [[np.dot(curTweetVec, queryVector), tweet] for tweet, curTweetVec in tweetVectors.items()]
    tweetScores.sort(reverse=True)
    scores = [x[0] for x in tweetScores]
    resultTweets = [x[1] for x in tweetScores]
    if len(resultTweets) == 0:
        print("No results found, try again")
        query = input()
        tweets = search_tf_idf(query, index) 
    return resultTweets, scores

# %%
def search_sbdm(query, index, fav_mean, rtw_mean, fav_rate = 1, rtw_rate = 0.5, date_rate = 0.5):
    stemming = PorterStemmer()
    stops = set(stopwords.words("english")).union(set({'amp', 'rt'}))
    
    query = getTerms(query, stemming, stops)
    tweets = set()

    for i, term in enumerate(query):
        try:
            # store in termDocs the ids of the docs that contain "term"                        
            termDocs = [posting[0] for posting in index[term]]
            
            # if this is the first word of the query, save all the tweets with this word
            if i == 0:
                tweets = tweets.union(termDocs)
            # for the next words, only keey those that contain that word and all the past words of the query
            else:
                tweets = tweets.intersection(termDocs)
        except:
            #term is not in index
            pass
    
    tweets = list(tweets)
    ranked_tweets, scores = rankTweets_sbdm(query, tweets, index, idf, tf, fav_mean, rtw_mean, fav_rate, rtw_rate, date_rate)   
    return ranked_tweets, scores

# %% [markdown]
# #### Testing

# %%
print("\033[1mInsert a query:\033[0m\n")
query = input()
fav_mean, rtw_mean = tweets_population(data, df)
ranked_tweets, scores = search_sbdm(query, index, fav_mean, rtw_mean, fav_rate = 1, rtw_rate = 0.5, date_rate = 0.5)    
top = 20

print("\n======================\n\033[1mTop {} results out of {} for the searched query:\033[0m\n".format(top, len(ranked_tweets)))
for d_id in ranked_tweets[:top]:
    print("\n\033[1mTweet id = {}\033[0m".format(d_id))
    print("   - Tweet_text = {} ".format(data[d_id]['org_text']))
    print("   - Tweet_user = {} ".format(data[d_id]['user']))
    print("   - Tweet_date = {} ".format(data[d_id]['date']))
    print("   - Tweet_hashtags = {} ".format(data[d_id]['hashtags']))
    print("   - Tweet_likes = {} ".format(data[d_id]['favorites']))
    print("   - Tweet_retweets = {} ".format(data[d_id]['retweets']))
    print("   - Tweet_url = {} ".format(data[d_id]['url']))
# Out:
# Insert a query:
#
# death risk
#
# ======================
# Top 20 results out of 18 for the searched query:
#
#
# Tweet id = 541
#    - Tweet_text = #Breastfeeding 🤱 is a critical first #FoodSystem that ensures nutrition, health &amp; development of 👶.
#
# It's sustainable, not for profit &amp; it helps reduce:
# 📉preventable deaths
# 📉the risk of noncommunicable diseases
# 📉the risk of overweight/obesity
#
# 👉https://t.co/0MM8lIxZAx https://t.co/lphfIbfaYt
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Thu Sep 23 15:52:59 +0000 2021
#    - Tweet_hashtags = ['Breastfeeding', 'FoodSystem']
#    - Tweet_likes = 139
#    - Tweet_retweets = 52
#    - Tweet_url = https://t.co/lphfIbfaYt
#
# Tweet id = 1386
#    - Tweet_text = These therapies - artesunate, imatinib and infliximab – were selected by an independent expert panel for their potential in reducing the risk of death in hospitalized #COVID19 patients. https://t.co/K6tk22NnFf
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Wed Aug 11 20:31:17 +0000 2021
#    - Tweet_hashtags = ['COVID19']
#    - Tweet_likes = 57
#    - Tweet_retweets = 21
#    - Tweet_url =
#
# Tweet id = 1100
#    - Tweet_text = #Hypertension - or elevated blood pressure - is a serious medical condition that significantly increases the risks of ❤, 🧠, kidney &amp; other diseases.
#
# It is a major cause of premature death worldwide.
#
# 👉 https://t.co/PEXOASL1Tg https://t.co/QIAIsudIxE
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Wed Aug 25 12:38:53 +0000 2021
#    - Tweet_hashtags = ['Hypertension']
#    - Tweet_likes = 145
#    - Tweet_retweets = 70
#    - Tweet_url = https://t.co/QIAIsudIxE
#
# Tweet id = 1074
#    - Tweet_text = "Cardiovascular diseases are the leading cause of death globally, and #hypertension is one of its main risk factors.
# More than 1.2 billion people live with hypertension."-@DrTedros
# https://t.co/zHeYfeQEFv
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Wed Aug 25 15:49:12 +0000 2021
#    - Tweet_hashtags = ['hypertension']
#    - Tweet_likes = 43
#    - Tweet_retweets = 21
#    - Tweet_url =
#
# Tweet id = 323
#    - Tweet_text = Today is #WorldHeartDay 💗
#
# #Hypertension - or elevated blood pressure - is a serious medical condition that significantly increases the risks of ❤, 🧠, kidney &amp; other diseases. It is a major cause of premature death worldwide.
#
# 👉 https://t.co/PEXOASL1Tg https://t.co/L6vriEK1yc
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Wed Sep 29 08:25:28 +0000 2021
#    - Tweet_hashtags = ['WorldHeartDay', 'Hypertension']
#    - Tweet_likes = 229
#    - Tweet_retweets = 107
#    - Tweet_url = https://t.co/L6vriEK1yc
#
# Tweet id = 1875
#    - Tweet_text = The death of a parent or caregiver can have immediate &amp; lifelong harmful consequences for children incl. increased risks of:
# 🔸physical, emotional &amp; sexual violence
# 🔸#MentalHealth problems
# 🔸family poverty
#
# 👉https://t.co/2Gbl49N7pH https://t.co/R7t5f1Bp2C
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Wed Jul 21 08:10:31 +0000 2021
#    - Tweet_hashtags = ['MentalHealth']
#    - Tweet_likes = 189
#    - Tweet_retweets = 63
#    - Tweet_url = https://t.co/R7t5f1Bp2C
#
# Tweet id = 696
#    - Tweet_text = According to the WHO/@ILO Joint Estimates, the risk factors at work which cause the most deaths annually are
#
# 🕥 long working hours
# 🏭 air pollution, gases &amp; fumes
# 🤕 injuries.
#
# More in detail 👉https://t.co/mEXoBqYt5g #WorkersHealth https://t.co/WFXTglLppp
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Fri Sep 17 14:29:01 +0000 2021
#    - Tweet_hashtags = ['WorkersHealth']
#    - Tweet_likes = 132
#    - Tweet_retweets = 57
#    - Tweet_url = https://t.co/WFXTglLppp
#
# Tweet id = 1523
#    - Tweet_text = Here is what we know about heart inflammation (myocarditis or pericarditis) and mRNA vaccines 👇
#
# The benefits of these vaccines 💉 greatly outweigh the risk of myocarditis &amp; pericarditis by preventing deaths &amp; hospitalisations due to #COVID19.
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Wed Aug 04 10:49:48 +0000 2021
#    - Tweet_hashtags = ['COVID19']
#    - Tweet_likes = 233
#    - Tweet_retweets = 101
#    - Tweet_url =
#
# Tweet id = 844
#    - Tweet_text = @DrTedros "3rd doses may be necessary for the most at-risk populations, where there's evidence of waning immunity against severe #COVID19 &amp; death – such as immunocompromised people who didn't respond sufficiently to their initial doses, or are no longer producing antibodies"-@DrTedros
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Wed Sep 08 14:48:16 +0000 2021
#    - Tweet_hashtags = ['COVID19']
#    - Tweet_likes = 92
#    - Tweet_retweets = 39
#    - Tweet_url =
#
# Tweet id = 793
#    - Tweet_text = Patients who are critically ill with severe #COVID19 are at higher risk of developing and dying from #sepsis
#
# If #sepsis is not recognized early and managed promptly, it can lead to septic shock, multiple organ failure &amp; death
#
# https://t.co/sSLSPAQFv8 https://t.co/PI0zUFL7um
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Mon Sep 13 09:48:20 +0000 2021
#    - Tweet_hashtags = ['COVID19', 'sepsis', 'sepsis']
#    - Tweet_likes = 264
#    - Tweet_retweets = 120
#    - Tweet_url = https://t.co/PI0zUFL7um
#
# Tweet id = 508
#    - Tweet_text = New data from over 90 countries highlights that the progress made in the fight against #tuberculosis is at risk with #COVID19 disruptions leading to 1.4 million additional people missing out on access to TB care in 2020 alone &amp; over half a million deaths. https://t.co/2CFqV8NQek
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Fri Sep 24 17:40:38 +0000 2021
#    - Tweet_hashtags = ['tuberculosis', 'COVID19']
#    - Tweet_likes = 48
#    - Tweet_retweets = 17
#    - Tweet_url =
#
# Tweet id = 753
#    - Tweet_text = @DrTedros "More than 5.7B [#COVID19 vaccine] doses have been administered globally, but only 2% of those have been administered in Africa. This leaves people at high risk of disease &amp; death exposed to a deadly virus against which many other people around the 🌍 enjoy protection"-@DrTedros
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Tue Sep 14 14:12:04 +0000 2021
#    - Tweet_hashtags = ['COVID19']
#    - Tweet_likes = 92
#    - Tweet_retweets = 45
#    - Tweet_url =
#
# Tweet id = 969
#    - Tweet_text = @DrTedros "3rd dose may be necessary for at most risk ppl, where there's evidence of waning immunity against severe #COVID19 disease &amp; death – such as the small group of immunocompromised ppl who didn't respond sufficiently to initial doses, or are no longer producing antibodies"-@DrTedros
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Wed Sep 01 15:13:26 +0000 2021
#    - Tweet_hashtags = ['COVID19']
#    - Tweet_likes = 72
#    - Tweet_retweets = 35
#    - Tweet_url =
#
# Tweet id = 97
#    - Tweet_text = It's #WorldMentalHealthDay.
#
# DYK: 1️⃣ in 1️⃣0️⃣0️⃣ deaths is by #suicide. For every suicide there are many more people who attempt suicide. A prior suicide attempt is an important risk factor.
# #LetsTalk https://t.co/cugMvd8oHu
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Sun Oct 10 08:21:24 +0000 2021
#    - Tweet_hashtags = ['WorldMentalHealthDay', 'suicide', 'LetsTalk']
#    - Tweet_likes = 298
#    - Tweet_retweets = 142
#    - Tweet_url = https://t.co/cugMvd8oHu
#
# Tweet id = 2289
#    - Tweet_text = 8 of the 41 SIDS face pressing health workforce challenges related to #HealthForAll.
#
# #COVID19 has heavily impacted the health workers – including their heightened risk of infection &amp; death, burnout, fatigue, discrimination &amp; mental health issues. https://t.co/xGEJBModDa
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Tue Jun 29 13:53:43 +0000 2021
#    - Tweet_hashtags = ['HealthForAll', 'COVID19']
#    - Tweet_likes = 28
#    - Tweet_retweets = 11
#    - Tweet_url =
#
# Tweet id = 2108
#    - Tweet_text = @DrTedros @G20 "This followed a comprehensive new analysis of 27 randomised trials involving nearly 11,000 patients, which found that treating hospitalised #COVID19 patients with IL-6 receptor blockers reduces the risk of death and the need for mechanical ventilation"-@DrTedros
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Wed Jul 07 13:30:22 +0000 2021
#    - Tweet_hashtags = ['COVID19']
#    - Tweet_likes = 48
#    - Tweet_retweets = 26
#    - Tweet_url =
#
# Tweet id = 1718
#    - Tweet_text = Hep B birthdose for babies can't wait:
# The vaccine protects your 👶 from this potentially life-threatening liver infection that can cause both acute &amp; chronic disease. #Hepatitis B can put people at high risk of death ☠️ from liver damage &amp; liver cancer
#
# 👉https://t.co/Em4LYylVms https://t.co/GVXr0WtdOw
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Wed Jul 28 12:13:41 +0000 2021
#    - Tweet_hashtags = ['Hepatitis']
#    - Tweet_likes = 161
#    - Tweet_retweets = 64
#    - Tweet_url = https://t.co/GVXr0WtdOw
#
# Tweet id = 2380
#    - Tweet_text = @DrTedros "As some countries ease public health and social measures, we are starting to see increases in #COVID19 transmission around the world. More cases means more hospitalizations, further stretching health workers and health systems, which increases the risk of death"-@DrTedros
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Fri Jun 25 15:33:14 +0000 2021
#    - Tweet_hashtags = ['COVID19']
#    - Tweet_likes = 69
#    - Tweet_retweets = 33
#    - Tweet_url =

# %% [markdown]
# ## Word2Vec + Cosine Similarity

# %% [markdown]
# #### Implementation

# %%
def rankTweets_Word2Vec(query, tweets, X, X_tweets, pos_to_id, ids_pos, model):
    # Get the ids of all words of the query
    words_ids = list()

    for word in query:
        if word in model.wv.key_to_index:
            words_ids.append(model.wv.key_to_index[word])
    
    query_w2v = X[words_ids,:].mean(axis=0)
    
    pos_list = [ids_pos[id_] for id_ in tweets]
    X_q = X_tweets[pos_list,:]
    
    cos_sim = np.dot(X_q, query_w2v) / (LA.norm(query_w2v) * np.linalg.norm(X_q, axis=1)) # Revisar
    
    # pares <cos_sim, id en data>
    tweetScores = [ [cos_sim[i], pos_to_id[pos_list[i]]] for i in range(len(pos_list))]
    tweetScores.sort(reverse=True)
    scores = [x[0] for x in tweetScores]
    resultTweets = [x[1] for x in tweetScores]
    #print document titles instead if document id's
    #resultDocs=[ titleIndex[x] for x in resultDocs ]
    if len(resultTweets) == 0:
        print("No results found, try again")
        query = input()
        tweets = search_tf_idf(query, index)    
    #print ('\n'.join(resultDocs), '\n')
    return resultTweets, scores

# %%
def search_Word2Vec(query, index, X, X_tweets, pos_ids, ids_pos, model):
    stemming = PorterStemmer()
    stops = set(stopwords.words("english")).union(set({'amp', 'rt'}))
    
    query = getTerms(query, stemming, stops)
    tweets = set()

    for i, term in enumerate(query):
        try:
            # store in termDocs the ids of the docs that contain "term"                        
            termDocs = [posting[0] for posting in index[term]]
            
            # if this is the first word of the query, save all the tweets with this word
            if i == 0:
                tweets = tweets.union(termDocs)
            # for the next words, only keey those that contain that word and all the past words of the query
            else:
                tweets = tweets.intersection(termDocs)
        except:
            #term is not in index
            pass
    
    tweets = list(tweets)
    
    ranked_tweets, scores = rankTweets_Word2Vec(query, tweets, X, X_tweets, pos_ids, ids_pos, model)   
    return ranked_tweets, scores

# %%
def tweets_word2vec(data):
    ## Transform each word to a 2D vector
    sentences = list()
    for tw_id in data:
        sentences.append(data[tw_id]['text'])

    model = Word2Vec(sentences)

    X = model.wv[model.wv.index_to_key]

    pos_ids = dict()
    ids_pos = dict()
    for i, id_ in enumerate(data.keys()):
        pos_ids[i] = id_
        ids_pos[id_] = i
        
    ## Represent each tweet as the mean of each of it's words

    # number of tweets
    n = len(sentences)
    # number of components of each tweet
    m = X.shape[1]
    X_tweets = np.zeros((n, m))

    for i, sentence in enumerate(sentences):
        words_ids = list()

        for word in sentence:
            if word in model.wv.key_to_index:
                words_ids.append(model.wv.key_to_index[word])

        X_tweets[i,:] = X[words_ids,:].mean(axis=0)
        
    return X, X_tweets, pos_ids, ids_pos, model

# %%
X, X_tweets, pos_ids, ids_pos, model = tweets_word2vec(data)

# %% [markdown]
# #### Testing

# %%
print("\033[1mInsert a query:\033[0m\n")
query = input()
ranked_tweets, scores = search_Word2Vec(query, index, X, X_tweets, pos_ids, ids_pos, model)    
top = 5

print("\n======================\n\033[1mTop {} results out of {} for the seached query:\033[0m\n".format(top, len(ranked_tweets)))
for d_id in ranked_tweets[:top] :
    print("\n\033[1mTweet id = {}\033[0m".format(d_id))
    print("   - Tweet_text = {} ".format(data[d_id]['org_text']))
    print("   - Tweet_user = {} ".format(data[d_id]['user']))
    print("   - Tweet_date = {} ".format(data[d_id]['date']))
    print("   - Tweet_hashtags = {} ".format(data[d_id]['hashtags']))
    print("   - Tweet_likes = {} ".format(data[d_id]['favorites']))
    print("   - Tweet_retweets = {} ".format(data[d_id]['retweets']))
    print("   - Tweet_url = {} ".format(data[d_id]['url']))
# Out:
# Insert a query:
#
# covid
#
# ======================
# Top 5 results out of 39 for the seached query:
#
#
# Tweet id = 1561
#    - Tweet_text = If you have recovered from #COVID19 but are still experiencing certain symptoms you could have post COVID-19 condition or "long COVID". What are these symptoms? How long do they last and are there any treatment options? Dr @diazjv explains in #ScienceIn5 ⬇️ https://t.co/vtDiBhZsJE
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Mon Aug 02 11:38:39 +0000 2021
#    - Tweet_hashtags = ['COVID19', 'ScienceIn5']
#    - Tweet_likes = 277
#    - Tweet_retweets = 154
#    - Tweet_url = https://t.co/vtDiBhZsJE
#
# Tweet id = 1045
#    - Tweet_text = ▶️ If you have #COVID19, is it safe to breastfeed your baby❓
#
# ▶️ Is it safe to get vaccinated against COVID-19 if you are breastfeeding❓
#
# ▶️ How can you keep your baby safe while breastfeeding 🤱 if you have COVID-19❓
#
# Dr Laurence Grummer-Strawn explains in #ScienceIn5. https://t.co/QMAq9TMY7A
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Mon Aug 30 10:43:22 +0000 2021
#    - Tweet_hashtags = ['COVID19', 'ScienceIn5']
#    - Tweet_likes = 219
#    - Tweet_retweets = 105
#    - Tweet_url = https://t.co/QMAq9TMY7A
#
# Tweet id = 200
#    - Tweet_text = 🆕 WHO clinical case definition for post #COVID19 condition, also called 'long COVID' https://t.co/WoiLcwsgJX https://t.co/Z0olrHlWPC
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Thu Oct 07 12:28:10 +0000 2021
#    - Tweet_hashtags = ['COVID19']
#    - Tweet_likes = 723
#    - Tweet_retweets = 373
#    - Tweet_url = https://t.co/Z0olrHlWPC
#
# Tweet id = 2257
#    - Tweet_text = Q&amp;A #AskWHO on COVID-19 vaccines effectiveness https://t.co/FEdfOREhjn
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Wed Jun 30 16:12:43 +0000 2021
#    - Tweet_hashtags = ['AskWHO']
#    - Tweet_likes = 219
#    - Tweet_retweets = 85
#    - Tweet_url =
#
# Tweet id = 1169
#    - Tweet_text = RT @DrTedros: Grateful to @LongCovidSOS and other partners who have done so much to improve understanding of post-COVID condition and its i…
#    - Tweet_user = Tedros Adhanom Ghebreyesus
#    - Tweet_date = Sat Aug 21 18:47:37 +0000 2021
#    - Tweet_hashtags = []
#    - Tweet_likes = 0
#    - Tweet_retweets = 118
#    - Tweet_url =

# %% [markdown]
# #### Testing with our selected queries

# %% [markdown]
# #### Query 1

# %%
print("\033[1mInsert a query:\033[0m\n")
query = q[0]
ranked_tweets, scores = search_Word2Vec(query, index, X, X_tweets, pos_ids, ids_pos, model)    
top = 20

print("\n======================\n\033[1mTop {} results out of {} for the seached query:\033[0m\n".format(top, len(ranked_tweets)))
for d_id in ranked_tweets[:top] :
    print("\n\033[1mTweet id = {}\033[0m".format(d_id))
    print("   - Tweet_text = {} ".format(data[d_id]['org_text']))
    print("   - Tweet_user = {} ".format(data[d_id]['user']))
    print("   - Tweet_date = {} ".format(data[d_id]['date']))
    print("   - Tweet_hashtags = {} ".format(data[d_id]['hashtags']))
    print("   - Tweet_likes = {} ".format(data[d_id]['favorites']))
    print("   - Tweet_retweets = {} ".format(data[d_id]['retweets']))
    print("   - Tweet_url = {} ".format(data[d_id]['url']))
# Out:
# Insert a query:
#
#
# ======================
# Top 20 results out of 731 for the seached query:
#
#
# Tweet id = 1820
#    - Tweet_text = When will the #COVID19 pandemic be over? https://t.co/bebc6ccur1
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Fri Jul 23 21:04:48 +0000 2021
#    - Tweet_hashtags = ['COVID19']
#    - Tweet_likes = 2878
#    - Tweet_retweets = 1243
#    - Tweet_url = https://t.co/bebc6ccur1
#
# Tweet id = 1828
#    - Tweet_text = #COVID19 vaccines 💉 are halal.
#
# Read more 👉https://t.co/y9lNOaCjgx https://t.co/mY2GHx0VYe
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Fri Jul 23 12:16:48 +0000 2021
#    - Tweet_hashtags = ['COVID19']
#    - Tweet_likes = 581
#    - Tweet_retweets = 307
#    - Tweet_url = https://t.co/mY2GHx0VYe
#
# Tweet id = 1043
#    - Tweet_text = Vaccines 💉 can’t stop #COVID19 alone, but by doing it all we can make a difference. https://t.co/746LlKfXQJ
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Mon Aug 30 15:33:03 +0000 2021
#    - Tweet_hashtags = ['COVID19']
#    - Tweet_likes = 583
#    - Tweet_retweets = 331
#    - Tweet_url = https://t.co/746LlKfXQJ
#
# Tweet id = 2356
#    - Tweet_text = What do we know about the #COVID19 Delta variant? ⬇️ https://t.co/0cxwxr3reC
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Sat Jun 26 21:23:42 +0000 2021
#    - Tweet_hashtags = ['COVID19']
#    - Tweet_likes = 777
#    - Tweet_retweets = 484
#    - Tweet_url = https://t.co/0cxwxr3reC
#
# Tweet id = 1659
#    - Tweet_text = Here is what we know about the #COVID19 Delta variant so far 👇
#
# https://t.co/QNJa5cmzu7
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Thu Jul 29 18:11:06 +0000 2021
#    - Tweet_hashtags = ['COVID19']
#    - Tweet_likes = 252
#    - Tweet_retweets = 113
#    - Tweet_url = https://t.co/QNJa5cmzu7
#
# Tweet id = 1834
#    - Tweet_text = All ingredients in #COVID19 vaccines are safe ✅.
#
# Read more 👉https://t.co/y9lNOaCjgx https://t.co/LhGTaZr2pv
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Fri Jul 23 07:56:45 +0000 2021
#    - Tweet_hashtags = ['COVID19']
#    - Tweet_likes = 290
#    - Tweet_retweets = 111
#    - Tweet_url = https://t.co/LhGTaZr2pv
#
# Tweet id = 2349
#    - Tweet_text = Are the existing vaccines protective against all #COVID19 variants of concern? https://t.co/VqhlciB7Pq
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Sun Jun 27 18:39:02 +0000 2021
#    - Tweet_hashtags = ['COVID19']
#    - Tweet_likes = 308
#    - Tweet_retweets = 148
#    - Tweet_url = https://t.co/VqhlciB7Pq
#
# Tweet id = 2386
#    - Tweet_text = Here is why you should get vaccinated even if you have had #COVID19 👇
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Fri Jun 25 13:27:47 +0000 2021
#    - Tweet_hashtags = ['COVID19']
#    - Tweet_likes = 432
#    - Tweet_retweets = 221
#    - Tweet_url =
#
# Tweet id = 2355
#    - Tweet_text = What is the #COVID19 Delta Plus variant⁉️ https://t.co/OgvcHiAfEP
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Sat Jun 26 21:29:18 +0000 2021
#    - Tweet_hashtags = ['COVID19']
#    - Tweet_likes = 734
#    - Tweet_retweets = 467
#    - Tweet_url = https://t.co/OgvcHiAfEP
#
# Tweet id = 884
#    - Tweet_text = Blood clots after receiving a #COVID19 AstraZeneca or the Janssen vaccine are rare. Get vaccinated, as soon as it’s your turn.
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Tue Sep 07 19:19:01 +0000 2021
#    - Tweet_hashtags = ['COVID19']
#    - Tweet_likes = 345
#    - Tweet_retweets = 147
#    - Tweet_url =
#
# Tweet id = 467
#    - Tweet_text = The book "My Hero is You 2021: how kids can hope with #COVID19" is available in Arabic, Bengali, Chinese, English, French, Portuguese, Russian, Spanish and Swahili.
# More translations are underway https://t.co/JiURHzrEDP https://t.co/JpmXi1Xi1u
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Mon Sep 27 07:21:05 +0000 2021
#    - Tweet_hashtags = ['COVID19']
#    - Tweet_likes = 212
#    - Tweet_retweets = 72
#    - Tweet_url = https://t.co/JpmXi1Xi1u
#
# Tweet id = 1944
#    - Tweet_text = #COVID19 vaccines 💉 only contain safe ingredients.
#
# Read more 👉https://t.co/y9lNOaCjgx https://t.co/Y8oJNSq9Sc
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Tue Jul 20 09:08:12 +0000 2021
#    - Tweet_hashtags = ['COVID19']
#    - Tweet_likes = 392
#    - Tweet_retweets = 148
#    - Tweet_url = https://t.co/Y8oJNSq9Sc
#
# Tweet id = 272
#    - Tweet_text = Vaccine inequity is:
#
# ⚠️ fueling a two track #COVID19 pandemic
# ⚠️ allowing variants to flourish
# ⚠️ threatening all the tools we have
#
# Vaccinating the 🌍 is essential if we are to get ahead of this virus. #VaccinEquity https://t.co/9RyR8lpNJc
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Fri Oct 01 17:19:47 +0000 2021
#    - Tweet_hashtags = ['COVID19', 'VaccinEquity']
#    - Tweet_likes = 268
#    - Tweet_retweets = 123
#    - Tweet_url = https://t.co/9RyR8lpNJc
#
# Tweet id = 2012
#    - Tweet_text = RT @WHO_Europe: What is an antibody? Find out more 👇
#
# #covid19 #covid_19 #coronavirus #vaccineswork https://t.co/VCTei6k7v9
#    - Tweet_user = WHO/Europe
#    - Tweet_date = Wed Jul 14 14:06:47 +0000 2021
#    - Tweet_hashtags = ['covid19', 'covid_19', 'coronavirus', 'vaccineswork']
#    - Tweet_likes = 0
#    - Tweet_retweets = 85
#    - Tweet_url = https://t.co/VCTei6k7v9
#
# Tweet id = 1416
#    - Tweet_text = The #COVID19 Delta variant of concern is the most transmissible variant so far.
#
# Here is what we know about it ⬇
# https://t.co/0cxwxr3reC
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Tue Aug 10 13:55:04 +0000 2021
#    - Tweet_hashtags = ['COVID19']
#    - Tweet_likes = 547
#    - Tweet_retweets = 290
#    - Tweet_url = https://t.co/0cxwxr3reC
#
# Tweet id = 1640
#    - Tweet_text = @DrTedros "Much of this increase is being driven by the highly-transmissible Delta variant, which has now been detected in at least 132 countries"-@DrTedros #COVID19
# https://t.co/NLOej8N2S1
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Fri Jul 30 14:24:36 +0000 2021
#    - Tweet_hashtags = ['COVID19']
#    - Tweet_likes = 57
#    - Tweet_retweets = 33
#    - Tweet_url =
#
# Tweet id = 1412
#    - Tweet_text = Do the current batch of approved #COVID19 vaccines protect us from the Delta variant❓
#
# WHO’s Chief Scientist Dr @doctorsoumya explains in #ScienceIn5 ⬇️
#
# https://t.co/kf93RkBgpt
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Tue Aug 10 15:07:56 +0000 2021
#    - Tweet_hashtags = ['COVID19', 'ScienceIn5']
#    - Tweet_likes = 179
#    - Tweet_retweets = 90
#    - Tweet_url = https://t.co/kf93RkBgpt
#
# Tweet id = 2392
#    - Tweet_text = LIVE Q&amp;A on #COVID19 variants and vaccines with @doctorsoumya. #AskWHO https://t.co/RFfQvz1kmp
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Thu Jun 24 15:38:09 +0000 2021
#    - Tweet_hashtags = ['COVID19', 'AskWHO']
#    - Tweet_likes = 508
#    - Tweet_retweets = 239
#    - Tweet_url =
#
# Tweet id = 718
#    - Tweet_text = RT @DrTedros: The longer #COVID19 vaccine inequity persists, the more:
# -the virus will keep circulating
# -the higher the chances that more v…
#    - Tweet_user = Tedros Adhanom Ghebreyesus
#    - Tweet_date = Wed Sep 15 10:32:27 +0000 2021
#    - Tweet_hashtags = ['COVID19']
#    - Tweet_likes = 0
#    - Tweet_retweets = 126
#    - Tweet_url =
#
# Tweet id = 269
#    - Tweet_text = Why we need a temporary moratorium on #COVID19 vaccine "boosters" - @DrMikeRyan and Dr Bruce Aylward explain 👇https://t.co/P0A0t0w8Vf
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Fri Oct 01 18:53:33 +0000 2021
#    - Tweet_hashtags = ['COVID19']
#    - Tweet_likes = 235
#    - Tweet_retweets = 97
#    - Tweet_url = https://t.co/P0A0t0w8Vf

# %% [markdown]
# #### Query 2

# %%
print("\033[1mInsert a query:\033[0m\n")
query = q[1]
ranked_tweets, scores = search_Word2Vec(query, index, X, X_tweets, pos_ids, ids_pos, model)    
top = 20

print("\n======================\n\033[1mTop {} results out of {} for the seached query:\033[0m\n".format(top, len(ranked_tweets)))
for d_id in ranked_tweets[:top] :
    print("\n\033[1mTweet id = {}\033[0m".format(d_id))
    print("   - Tweet_text = {} ".format(data[d_id]['org_text']))
    print("   - Tweet_user = {} ".format(data[d_id]['user']))
    print("   - Tweet_date = {} ".format(data[d_id]['date']))
    print("   - Tweet_hashtags = {} ".format(data[d_id]['hashtags']))
    print("   - Tweet_likes = {} ".format(data[d_id]['favorites']))
    print("   - Tweet_retweets = {} ".format(data[d_id]['retweets']))
    print("   - Tweet_url = {} ".format(data[d_id]['url']))
# Out:
# Insert a query:
#
#
# ======================
# Top 20 results out of 15 for the seached query:
#
#
# Tweet id = 1959
#    - Tweet_text = 💉💉💉💉
# 💉💉💉💉
# 💉💉💉💉
# 💉💉💉💉
# 💉💉💉💉                 💉💉💉💉
# 💉💉💉💉                 💉💉💉💉
#
# COVID-19 vaccines     COVID-19 vaccines
# in 10 countries             in the rest of the 🌍
#
# #VaccinEquity is 🗝️ to ending the pandemic, together!
#
# #WorldEmojiDay
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Sat Jul 17 16:24:23 +0000 2021
#    - Tweet_hashtags = ['VaccinEquity', 'WorldEmojiDay']
#    - Tweet_likes = 3486
#    - Tweet_retweets = 1517
#    - Tweet_url =
#
# Tweet id = 4
#    - Tweet_text = RT @opsoms: If you are fully vaccinated 💉💉, can you still get COVID-19?
#
# 🚨 It does not matter if you are vaccinated or if you are still waiting, yes ...
#    - Tweet_user = OPS/OMS
#    - Tweet_date = Wed Oct 13 05:47:10 +0000 2021
#    - Tweet_hashtags = []
#    - Tweet_likes = 0
#    - Tweet_retweets = 43
#    - Tweet_url = https://t.co/YxWlXt1QWr
#
# Tweet id = 1849
#    - Tweet_text = COVID-19 vaccine inequity is undermining 🌍 economic recovery. 🆕WHO, @UNDP and @BlavatnikSchool Dashboard on #VaccinEquity finds that low-income countries would add $38B to their GDP forecast if they had the same vaccination rate as high-income countries
# https://t.co/BsYF2eYL1G
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Thu Jul 22 13:43:53 +0000 2021
#    - Tweet_hashtags = ['VaccinEquity']
#    - Tweet_likes = 383
#    - Tweet_retweets = 168
#    - Tweet_url =
#
# Tweet id = 935
#    - Tweet_text = RT @WHONepal: Nepal has administered more than 🔟million doses of COVID-19 💉💉💉, fully vaccinating 15% of its population. This feat wouldn't…
#    - Tweet_user = WHO Nepal
#    - Tweet_date = Thu Sep 02 16:38:12 +0000 2021
#    - Tweet_hashtags = []
#    - Tweet_likes = 0
#    - Tweet_retweets = 101
#    - Tweet_url = https://t.co/9E62I3aVpk
#
# Tweet id = 904
#    - Tweet_text = #COVID19 variants &amp; vaccines:
#
# ✅ COVID-19 vaccines provide strong protection against serious illness &amp; death
# ✅ Get all necessary doses to develop maximum protection
# ✅ Continue practicing all the protective behaviours even after vaccination to stop COVID-19 variants
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Mon Sep 06 08:09:59 +0000 2021
#    - Tweet_hashtags = ['COVID19']
#    - Tweet_likes = 352
#    - Tweet_retweets = 169
#    - Tweet_url =
#
# Tweet id = 61
#    - Tweet_text = RT @WHOPhilippines: Vaccines can’t stop #COVID19 alone, but by doing it all we can help protect ourselves and our loved ones against COVID-…
#    - Tweet_user = World Health Organization Philippines
#    - Tweet_date = Mon Oct 11 04:39:10 +0000 2021
#    - Tweet_hashtags = ['COVID19']
#    - Tweet_likes = 0
#    - Tweet_retweets = 71
#    - Tweet_url = https://t.co/jTw5stAksU
#
# Tweet id = 310
#    - Tweet_text = RT @WHOAFRO: Join tomorrow's media briefing on the #COVID19 pandemic &amp; the global 10% COVID-19 vaccination milestones reached by countries…
#    - Tweet_user = WHO African Region
#    - Tweet_date = Wed Sep 29 19:01:27 +0000 2021
#    - Tweet_hashtags = ['COVID19']
#    - Tweet_likes = 0
#    - Tweet_retweets = 21
#    - Tweet_url = https://t.co/ssx72Lji0e
#
# Tweet id = 2253
#    - Tweet_text = The heads of the four organizations discussed the urgency of increasing supplies of #COVID19 vaccines, therapeutics and diagnostics for developing countries; and practical &amp; effective ways to track, coordinate and advance delivery of COVID-19 vaccines to developing countries. https://t.co/fpISmcwQc2
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Wed Jun 30 20:04:47 +0000 2021
#    - Tweet_hashtags = ['COVID19']
#    - Tweet_likes = 67
#    - Tweet_retweets = 17
#    - Tweet_url =
#
# Tweet id = 1846
#    - Tweet_text = Richer countries are projected to both vaccinate &amp; recover quicker from #COVID19. Poorer countries haven’t even been able to vaccinate their health workers &amp; most at-risk populations, and may not achieve pre-COVID-19 levels of growth until 2024.
#
# https://t.co/48frkTNNmC https://t.co/SuItOFgaxZ
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Thu Jul 22 15:20:11 +0000 2021
#    - Tweet_hashtags = ['COVID19']
#    - Tweet_likes = 130
#    - Tweet_retweets = 65
#    - Tweet_url = https://t.co/SuItOFgaxZ
#
# Tweet id = 1565
#    - Tweet_text = Are you involved in the costing, budgeting or financing processes of #COVID19 vaccine delivery in your country?
#
# Join our 🆕 #OpenWHO course to learn how to use the COVID-19 Vaccine Introduction and deployment Costing Tool.
#
# 👉 https://t.co/vyXfuxXSDB https://t.co/XPr1caIFg6
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Mon Aug 02 10:46:05 +0000 2021
#    - Tweet_hashtags = ['COVID19', 'OpenWHO']
#    - Tweet_likes = 146
#    - Tweet_retweets = 31
#    - Tweet_url = https://t.co/XPr1caIFg6
#
# Tweet id = 300
#    - Tweet_text = RT @WHOAFRO: 📺 LIVE: @WHOAFRO media briefing on the #COVID19 pandemic &amp; the global 10% COVID-19 vaccination milestones reached by countries…
#    - Tweet_user = WHO African Region
#    - Tweet_date = Thu Sep 30 10:07:43 +0000 2021
#    - Tweet_hashtags = ['COVID19']
#    - Tweet_likes = 0
#    - Tweet_retweets = 27
#    - Tweet_url =
#
# Tweet id = 1310
#    - Tweet_text = Getting vaccinated against #COVID19 helps protect you from getting sick. As soon as it's your turn, take your vaccine!
#
# All approved COVID-19 vaccines have been thoroughly tested, and all provide a high degree of protection against getting seriously ill &amp; dying from the disease. https://t.co/bYpU3WvpuM
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Sun Aug 15 06:01:21 +0000 2021
#    - Tweet_hashtags = ['COVID19']
#    - Tweet_likes = 299
#    - Tweet_retweets = 120
#    - Tweet_url = https://t.co/bYpU3WvpuM
#
# Tweet id = 2257
#    - Tweet_text = Q&amp;A #AskWHO on COVID-19 vaccines effectiveness https://t.co/FEdfOREhjn
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Wed Jun 30 16:12:43 +0000 2021
#    - Tweet_hashtags = ['AskWHO']
#    - Tweet_likes = 219
#    - Tweet_retweets = 85
#    - Tweet_url =
#
# Tweet id = 1045
#    - Tweet_text = ▶️ If you have #COVID19, is it safe to breastfeed your baby❓
#
# ▶️ Is it safe to get vaccinated against COVID-19 if you are breastfeeding❓
#
# ▶️ How can you keep your baby safe while breastfeeding 🤱 if you have COVID-19❓
#
# Dr Laurence Grummer-Strawn explains in #ScienceIn5. https://t.co/QMAq9TMY7A
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Mon Aug 30 10:43:22 +0000 2021
#    - Tweet_hashtags = ['COVID19', 'ScienceIn5']
#    - Tweet_likes = 219
#    - Tweet_retweets = 105
#    - Tweet_url = https://t.co/QMAq9TMY7A
#
# Tweet id = 1328
#    - Tweet_text = RT @Ops_Paraguay: 👥Community health is at the center of vaccination against COVID-19 in indigenous communities of Paraguay
# ➕INFO👉:…
#    - Tweet_user = OPS OMS Paraguay
#    - Tweet_date = Fri Aug 13 18:01:02 +0000 2021
#    - Tweet_hashtags = []
#    - Tweet_likes = 0
#    - Tweet_retweets = 27
#    - Tweet_url = https://t.co/4shBOQ3bZW

# %% [markdown]
# #### Query 3

# %%
print("\033[1mInsert a query:\033[0m\n")
query = q[2]
ranked_tweets, scores = search_Word2Vec(query, index, X, X_tweets, pos_ids, ids_pos, model)    
top = 20

print("\n======================\n\033[1mTop {} results out of {} for the seached query:\033[0m\n".format(top, len(ranked_tweets)))
for d_id in ranked_tweets[:top] :
    print("\n\033[1mTweet id = {}\033[0m".format(d_id))
    print("   - Tweet_text = {} ".format(data[d_id]['org_text']))
    print("   - Tweet_user = {} ".format(data[d_id]['user']))
    print("   - Tweet_date = {} ".format(data[d_id]['date']))
    print("   - Tweet_hashtags = {} ".format(data[d_id]['hashtags']))
    print("   - Tweet_likes = {} ".format(data[d_id]['favorites']))
    print("   - Tweet_retweets = {} ".format(data[d_id]['retweets']))
    print("   - Tweet_url = {} ".format(data[d_id]['url']))
# Out:
# Insert a query:
#
#
# ======================
# Top 20 results out of 36 for the seached query:
#
#
# Tweet id = 516
#    - Tweet_text = Global leaders attending the 🇺🇸-hosted Global #COVID19 Summit re-affirm their commitment to ending the acute phase of the pandemic, and the goals of the @ACTAccelerator, by agreeing targets to provide equitable access to:
# ✅tests
# ✅treatments
# ✅vaccines
#
# 👉https://t.co/T3utXY29Bv https://t.co/njtxVXEbs0
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Fri Sep 24 16:13:12 +0000 2021
#    - Tweet_hashtags = ['COVID19']
#    - Tweet_likes = 193
#    - Tweet_retweets = 63
#    - Tweet_url = https://t.co/njtxVXEbs0
#
# Tweet id = 1087
#    - Tweet_text = "Most recently, the @g20org established a High-Level Independent Panel on Financing the Global Commons for Pandemic Preparedness and Response."-@DrTedros
# https://t.co/5U2cYU5mDm
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Wed Aug 25 15:34:09 +0000 2021
#    - Tweet_hashtags = []
#    - Tweet_likes = 33
#    - Tweet_retweets = 10
#    - Tweet_url =
#
# Tweet id = 1005
#    - Tweet_text = @DrTedros "But the lessons from West Africa were not sufficient to prepare the world for a global pandemic of a respiratory pathogen"-@DrTedros https://t.co/BIB3WZmPep
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Wed Sep 01 14:13:49 +0000 2021
#    - Tweet_hashtags = []
#    - Tweet_likes = 48
#    - Tweet_retweets = 20
#    - Tweet_url =
#
# Tweet id = 996
#    - Tweet_text = @DrTedros "There have been several reviews of the global response to the #COVID19 pandemic, with recommendations for countries and for WHO about what we can do to keep the world safer in future"-@DrTedros
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Wed Sep 01 14:29:07 +0000 2021
#    - Tweet_hashtags = ['COVID19']
#    - Tweet_likes = 51
#    - Tweet_retweets = 9
#    - Tweet_url =
#
# Tweet id = 2110
#    - Tweet_text = @DrTedros @G20 "We’re making scientific breakthroughs in global trials, but the impact is limited if we don’t share them equitably. It’s not charity, it’s the best way to end the acute stage of this pandemic, slow virus variants down and drive a global economic recovery"-@DrTedros #ACTogether
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Wed Jul 07 13:27:29 +0000 2021
#    - Tweet_hashtags = ['ACTogether']
#    - Tweet_likes = 74
#    - Tweet_retweets = 30
#    - Tweet_url =
#
# Tweet id = 498
#    - Tweet_text = "4⃣ A global commitment to preparedness &amp; response in the form of an international agreement, compact or treaty that guarantees highest level political commitment for strengthening global collaboration on preventing &amp; addressing pandemics &amp; epidemics"- @DrTedros #COVIDSummit
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Fri Sep 24 18:03:04 +0000 2021
#    - Tweet_hashtags = ['COVIDSummit']
#    - Tweet_likes = 31
#    - Tweet_retweets = 10
#    - Tweet_url =
#
# Tweet id = 2197
#    - Tweet_text = "This is the best way to slow the [#COVID19] pandemic, save lives, drive a truly global economic recovery and along the way prevent further dangerous variants from getting the upper hand."-@DrTedros
# https://t.co/piygNnMPYg
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Fri Jul 02 13:00:35 +0000 2021
#    - Tweet_hashtags = ['COVID19']
#    - Tweet_likes = 34
#    - Tweet_retweets = 13
#    - Tweet_url =
#
# Tweet id = 1003
#    - Tweet_text = @DrTedros "One of the most clear is the need for new, powerful systems and tools for global surveillance, to collect, analyse and disseminate data on outbreaks with the potential to become epidemics and pandemics"-@DrTedros https://t.co/wWkWwGkt4b
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Wed Sep 01 14:14:35 +0000 2021
#    - Tweet_hashtags = []
#    - Tweet_likes = 66
#    - Tweet_retweets = 20
#    - Tweet_url =
#
# Tweet id = 451
#    - Tweet_text = @DrTedros @EmmanuelMacron @ACTAccelerator "But the close relationship between #France and WHO goes back much further than the #COVID19 pandemic. Indeed, the #WHOAcademy is the latest expression of 🇫🇷’s longstanding support for WHO and its historic commitment to advancing global health"-@DrTedros https://t.co/ZNQpzF6rVm
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Mon Sep 27 14:17:55 +0000 2021
#    - Tweet_hashtags = ['France', 'COVID19', 'WHOAcademy']
#    - Tweet_likes = 40
#    - Tweet_retweets = 22
#    - Tweet_url = https://t.co/ZNQpzF6rVm
#
# Tweet id = 161
#    - Tweet_text = Since the beginning of the #COVID19 pandemic, WHO &amp; partners have mounted a response at an unprecedented global scale.
#
# We continue to provide critical support and guidance to countries with the Strategic Preparedness Response Plan (SPRP) 👉https://t.co/g99Aikj9Kg https://t.co/bgRLIrGEyD
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Thu Oct 07 20:36:37 +0000 2021
#    - Tweet_hashtags = ['COVID19']
#    - Tweet_likes = 323
#    - Tweet_retweets = 75
#    - Tweet_url = https://t.co/bgRLIrGEyD
#
# Tweet id = 1084
#    - Tweet_text = "They all recognize the need for better global governance of pandemic preparedness and response.
# They all recognize the need for better systems and tools to prevent, prepare for, detect and respond rapidly to epidemics and pandemics."-@DrTedros
# https://t.co/fFBmhTFsbo
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Wed Aug 25 15:37:45 +0000 2021
#    - Tweet_hashtags = []
#    - Tweet_likes = 37
#    - Tweet_retweets = 13
#    - Tweet_url =
#
# Tweet id = 983
#    - Tweet_text = @DrTedros @Chikwe_I @schwartlanderb @erna_solberg @NAkufoAddo @GlobalGoalsUN @ACTAccelerator "In October last year, I was honoured to speak to Chancellor Merkel, which is when we first discussed the idea for a new centre that would serve as a global platform to enhance global capacity for pandemic and epidemic intelligence"-@DrTedros https://t.co/p4qUYVCdFX
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Wed Sep 01 14:45:20 +0000 2021
#    - Tweet_hashtags = []
#    - Tweet_likes = 59
#    - Tweet_retweets = 20
#    - Tweet_url =
#
# Tweet id = 2259
#    - Tweet_text = #COVID19 has worsened existing gender inequalities and rolled back progress for the rights of women and girls in the 🌍
#
# Equality must be at the heart of the global response to building back from the pandemic.
#
# 👉 https://t.co/52NIwTDRdK https://t.co/CR0ZHaZXhA
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Wed Jun 30 15:19:42 +0000 2021
#    - Tweet_hashtags = ['COVID19']
#    - Tweet_likes = 151
#    - Tweet_retweets = 31
#    - Tweet_url = https://t.co/CR0ZHaZXhA
#
# Tweet id = 140
#    - Tweet_text = 🚨 Progress is under threat &amp; resources lacking to address new outbreaks, variants &amp; global vaccine inequity.
#
# Here are the resources needed to fight the #COVID19 pandemic 👉https://t.co/y3fu6evL33 https://t.co/AWUYpNyXCu
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Fri Oct 08 21:04:49 +0000 2021
#    - Tweet_hashtags = ['COVID19']
#    - Tweet_likes = 70
#    - Tweet_retweets = 15
#    - Tweet_url = https://t.co/AWUYpNyXCu
#
# Tweet id = 1129
#    - Tweet_text = "You will also be discussing the challenges facing our organization, including the challenge of sustainable financing.
# The pandemic has shown that the world needs an empowered and sustainably financed WHO at the centre of the global health architecture."-@DrTedros at #RC71AFRO
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Tue Aug 24 09:34:08 +0000 2021
#    - Tweet_hashtags = ['RC71AFRO']
#    - Tweet_likes = 31
#    - Tweet_retweets = 9
#    - Tweet_url =
#
# Tweet id = 500
#    - Tweet_text = "2⃣ Fully and flexibly funding global needs to respond to the pandemic. This includes the @ACTAccelerator to ensure access to vaccines, through #COVAX, diagnostics, treatments and personal protective equipment to countries in need"- @DrTedros #COVIDSummit
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Fri Sep 24 18:02:30 +0000 2021
#    - Tweet_hashtags = ['COVAX', 'COVIDSummit']
#    - Tweet_likes = 25
#    - Tweet_retweets = 9
#    - Tweet_url =
#
# Tweet id = 1698
#    - Tweet_text = "The #COVID19 pandemic has revealed two critical areas in which the world needs to do far more to bolster global health security: strengthening and sharing."-@DrMikeRyan
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Wed Jul 28 20:48:43 +0000 2021
#    - Tweet_hashtags = ['COVID19']
#    - Tweet_likes = 25
#    - Tweet_retweets = 11
#    - Tweet_url =
#
# Tweet id = 1991
#    - Tweet_text = @DrTedros "As I think everyone knows, 🇩🇪 has been one of the leading lights in the fight against the #COVID19 pandemic globally, under your leadership [@jensspahn] and that of Chancellor Merkel"-@DrTedros #ACTogether
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Thu Jul 15 12:15:19 +0000 2021
#    - Tweet_hashtags = ['COVID19', 'ACTogether']
#    - Tweet_likes = 66
#    - Tweet_retweets = 14
#    - Tweet_url =
#
# Tweet id = 1141
#    - Tweet_text = "That’s why there is now an emerging global consensus for the idea of an international treaty or other legal instrument, to provide the basis for improved international cooperation to prepare for, detect and respond to epidemics and pandemics."-@DrTedros at #RC71AFRO
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Tue Aug 24 09:22:07 +0000 2021
#    - Tweet_hashtags = ['RC71AFRO']
#    - Tweet_likes = 66
#    - Tweet_retweets = 16
#    - Tweet_url =
#
# Tweet id = 652
#    - Tweet_text = .@GordonBrown has tirelessly called on wealthy nations as well as the private sector to ensure the equitable distribution of #COVID19 vaccines, advocating for a concerted global effort - rooted in science &amp; sound economics – to save lives, end the pandemic &amp; restore livelihoods. https://t.co/LoL5sQ9YB0
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Sun Sep 19 23:41:26 +0000 2021
#    - Tweet_hashtags = ['COVID19']
#    - Tweet_likes = 234
#    - Tweet_retweets = 62
#    - Tweet_url =

# %% [markdown]
# #### Query 4

# %%
print("\033[1mInsert a query:\033[0m\n")
query = q[3]
ranked_tweets, scores = search_Word2Vec(query, index, X, X_tweets, pos_ids, ids_pos, model)    
top = 20

print("\n======================\n\033[1mTop {} results out of {} for the seached query:\033[0m\n".format(top, len(ranked_tweets)))
for d_id in ranked_tweets[:top] :
    print("\n\033[1mTweet id = {}\033[0m".format(d_id))
    print("   - Tweet_text = {} ".format(data[d_id]['org_text']))
    print("   - Tweet_user = {} ".format(data[d_id]['user']))
    print("   - Tweet_date = {} ".format(data[d_id]['date']))
    print("   - Tweet_hashtags = {} ".format(data[d_id]['hashtags']))
    print("   - Tweet_likes = {} ".format(data[d_id]['favorites']))
    print("   - Tweet_retweets = {} ".format(data[d_id]['retweets']))
    print("   - Tweet_url = {} ".format(data[d_id]['url']))
# Out:
# Insert a query:
#
#
# ======================
# Top 20 results out of 64 for the seached query:
#
#
# Tweet id = 150
#    - Tweet_text = For more information on #mentalhealth , please visit 👇https://t.co/n3Iaz7WUVf
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Fri Oct 08 13:40:30 +0000 2021
#    - Tweet_hashtags = ['mentalhealth']
#    - Tweet_likes = 68
#    - Tweet_retweets = 20
#    - Tweet_url =
#
# Tweet id = 47
#    - Tweet_text = RT @WHOSEARO: Spending too much time on your laptop 🧑🏽‍💻 or mobile phone 📲? Please don’t. Take care of your #mentalhealth.
#
# #WorldMentalHea…
#    - Tweet_user = WHO South-East Asia
#    - Tweet_date = Mon Oct 11 04:45:10 +0000 2021
#    - Tweet_hashtags = ['mentalhealth']
#    - Tweet_likes = 0
#    - Tweet_retweets = 21
#    - Tweet_url = https://t.co/Fiq2amvmg2
#
# Tweet id = 225
#    - Tweet_text = Block your calendars for @TwitterSpaces chat on #MentalHealth &amp; young people 👇
#
# 🗓 Saturday, 9 October
# 🕛 12:00pm CEST
#
# #AskWHO
# #WorldMentalHealthDay
#
#  https://t.co/qbpYqqWyTq
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Tue Oct 05 20:52:21 +0000 2021
#    - Tweet_hashtags = ['MentalHealth', 'AskWHO', 'WorldMentalHealthDay']
#    - Tweet_likes = 199
#    - Tweet_retweets = 81
#    - Tweet_url =
#
# Tweet id = 133
#    - Tweet_text = RT @WHO: Have you set your reminder yet?
#
# Don't miss @TwitterSpaces chat on #mentalhealth &amp; young people with:
# 🎙 Chiara Servili, WHO Child…
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Sat Oct 09 07:59:56 +0000 2021
#    - Tweet_hashtags = ['mentalhealth']
#    - Tweet_likes = 0
#    - Tweet_retweets = 53
#    - Tweet_url =
#
# Tweet id = 43
#    - Tweet_text = RT @WHO_Europe: This #WorldMentalHealthDay, we’re asking: how can we make #MentalHealth care a reality for all?
# Here are some ideas:
#
# ✅Adv…
#    - Tweet_user = WHO/Europe
#    - Tweet_date = Mon Oct 11 04:45:56 +0000 2021
#    - Tweet_hashtags = ['WorldMentalHealthDay', 'MentalHealth']
#    - Tweet_likes = 0
#    - Tweet_retweets = 50
#    - Tweet_url = https://t.co/8jOirQ80hN
#
# Tweet id = 240
#    - Tweet_text = This August, with the help of current and former football players, WHO, @ASEAN and @FIFAcom launched the #ReachOut campaign for better #MentalHealth.
#
# https://t.co/IjpYG8ktiI
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Tue Oct 05 06:25:37 +0000 2021
#    - Tweet_hashtags = ['ReachOut', 'MentalHealth']
#    - Tweet_likes = 66
#    - Tweet_retweets = 17
#    - Tweet_url =
#
# Tweet id = 139
#    - Tweet_text = Have you set your reminder yet?
#
# Don't miss @TwitterSpaces chat on #mentalhealth &amp; young people with:
# 🎙 Chiara Servili, WHO Child &amp; Adolescent Mental Health Expert
# 🎙 @ZeinabHijazi, @UNICEF Senior Mental Health Technical Advisor
# 🎙 @tolusefrancis, #mentalhealth advocate from 🇳🇬 https://t.co/EwSSWeXjnp
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Fri Oct 08 21:13:25 +0000 2021
#    - Tweet_hashtags = ['mentalhealth', 'mentalhealth']
#    - Tweet_likes = 188
#    - Tweet_retweets = 53
#    - Tweet_url =
#
# Tweet id = 138
#    - Tweet_text = RT @DrTedros: Great profile piece, worth reading ahead of #WorldMentalHealthDay, about Dévora Kestel, global leader in #mentalhealth policy…
#    - Tweet_user = Tedros Adhanom Ghebreyesus
#    - Tweet_date = Fri Oct 08 21:45:17 +0000 2021
#    - Tweet_hashtags = ['WorldMentalHealthDay', 'mentalhealth']
#    - Tweet_likes = 0
#    - Tweet_retweets = 64
#    - Tweet_url =
#
# Tweet id = 46
#    - Tweet_text = RT @WHOSEARO: It is important to stay in touch with your loved ones
# 📱👩🏽‍💻 during these difficult times.
#
# #mentalhealth #WorldMentalHealth…
#    - Tweet_user = WHO South-East Asia
#    - Tweet_date = Mon Oct 11 04:45:16 +0000 2021
#    - Tweet_hashtags = ['mentalhealth']
#    - Tweet_likes = 0
#    - Tweet_retweets = 43
#    - Tweet_url = https://t.co/7vDNyUflh7
#
# Tweet id = 44
#    - Tweet_text = RT @WHOSEARO: Sometimes, the news may get too much for your #mentalhealth. It’s okay to switch off ❌ at times.
#
# #WorldMentalHealthDay https…
#    - Tweet_user = WHO South-East Asia
#    - Tweet_date = Mon Oct 11 04:45:39 +0000 2021
#    - Tweet_hashtags = ['mentalhealth', 'WorldMentalHealthDay']
#    - Tweet_likes = 0
#    - Tweet_retweets = 25
#    - Tweet_url = https://t.co/FCD9UWx7FX
#
# Tweet id = 1548
#    - Tweet_text = #Depression affects more than 260 million people in the world while around half of all #mentalhealth conditions start by age 14.
#
# #Suicide is the fourth leading cause of death in young people aged 15-29.
#
# ⚽️ https://t.co/VMZxBomqlZ #ReachOut
#
# https://t.co/DElF0AG8Rn
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Tue Aug 03 05:41:24 +0000 2021
#    - Tweet_hashtags = ['Depression', 'mentalhealth', 'Suicide', 'ReachOut']
#    - Tweet_likes = 329
#    - Tweet_retweets = 152
#    - Tweet_url = https://t.co/DElF0AG8Rn
#
# Tweet id = 152
#    - Tweet_text = Government health budgets spent on #MentalHealth has scarcely changed during the last years, still hovering around 2% https://t.co/J0uKvKWZ46 https://t.co/vmcB98hvF0
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Fri Oct 08 12:21:06 +0000 2021
#    - Tweet_hashtags = ['MentalHealth']
#    - Tweet_likes = 151
#    - Tweet_retweets = 65
#    - Tweet_url = https://t.co/vmcB98hvF0
#
# Tweet id = 91
#    - Tweet_text = Set your reminder and join our @TwitterSpaces chat about #MentalHealth in emergencies later today:
#
# ⏱ 16:00h CEST
# 🎙 @Fahmy__Hanna__ /WHO and @VentevogelPeter/@Refugees
#
# #WorldMentalHealthDay #AskWHO
#
# https://t.co/8n63JwDKKL
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Sun Oct 10 11:09:46 +0000 2021
#    - Tweet_hashtags = ['MentalHealth', 'WorldMentalHealthDay', 'AskWHO']
#    - Tweet_likes = 224
#    - Tweet_retweets = 86
#    - Tweet_url =
#
# Tweet id = 1550
#    - Tweet_text = WHO, @ASEAN and @FIFAcom launched the #ReachOut campaign for better #mentalhealth with the support of  past and current football ⚽️ players👉 https://t.co/VMZxBomqlZ https://t.co/bTzu8NuZ6W
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Mon Aug 02 21:46:00 +0000 2021
#    - Tweet_hashtags = ['ReachOut', 'mentalhealth']
#    - Tweet_likes = 364
#    - Tweet_retweets = 101
#    - Tweet_url = https://t.co/bTzu8NuZ6W
#
# Tweet id = 81
#    - Tweet_text = RT @DrTedros: This #WorldMentalHealthDay, @WHO is also providing new easy-to-read materials on how to take care of your own #mentalhealth a…
#    - Tweet_user = Tedros Adhanom Ghebreyesus
#    - Tweet_date = Sun Oct 10 15:45:54 +0000 2021
#    - Tweet_hashtags = ['WorldMentalHealthDay', 'mentalhealth']
#    - Tweet_likes = 0
#    - Tweet_retweets = 44
#    - Tweet_url =
#
# Tweet id = 70
#    - Tweet_text = Some of the most common #mentalhealth conditions, depression and anxiety, can be treated with talking therapies, medication, or a combination of these.
#
# Laxmi, 🇮🇳, shares how counsellor's support helped her overcome feelings of #depression.
#
# #WorldMentalHealthDay https://t.co/s4Ca8VJaT0
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Sun Oct 10 19:52:35 +0000 2021
#    - Tweet_hashtags = ['mentalhealth', 'depression', 'WorldMentalHealthDay']
#    - Tweet_likes = 111
#    - Tweet_retweets = 35
#    - Tweet_url = https://t.co/s4Ca8VJaT0
#
# Tweet id = 117
#    - Tweet_text = Set reminder to join our @TwitterSpaces chat about #MentalHealth  care for all:
#
# 🗓 10 October
# ⏱ 12:00 pm CEST
# 🎙 @AliSchafer4, @DoctorJas &amp; @DebraMachando
#
# #WorldMentalHealthDay
#
#  https://t.co/nvS5jv75dP
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Sat Oct 09 15:14:38 +0000 2021
#    - Tweet_hashtags = ['MentalHealth', 'WorldMentalHealthDay']
#    - Tweet_likes = 231
#    - Tweet_retweets = 84
#    - Tweet_url =
#
# Tweet id = 147
#    - Tweet_text = RT @DrTedros: .@WHO issued the #MentalHealth Atlas today, highlighting a global shortfall in investment for mental health care. It is extre…
#    - Tweet_user = Tedros Adhanom Ghebreyesus
#    - Tweet_date = Fri Oct 08 14:23:53 +0000 2021
#    - Tweet_hashtags = ['MentalHealth']
#    - Tweet_likes = 0
#    - Tweet_retweets = 98
#    - Tweet_url =
#
# Tweet id = 239
#    - Tweet_text = LIVE with @DrTedros at the Global #mentalhealth summit ⬇️
#
# #MindRightsNow
#
# https://t.co/M3JiSuUweA
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Tue Oct 05 07:10:03 +0000 2021
#    - Tweet_hashtags = ['mentalhealth', 'MindRightsNow']
#    - Tweet_likes = 187
#    - Tweet_retweets = 58
#    - Tweet_url =
#
# Tweet id = 38
#    - Tweet_text = RT @WHO: Close to 1️⃣ billion people have a #mentalhealth disorder. Despite the magnitude of mental ill health, relatively few people aroun…
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Mon Oct 11 07:40:09 +0000 2021
#    - Tweet_hashtags = ['mentalhealth']
#    - Tweet_likes = 0
#    - Tweet_retweets = 85
#    - Tweet_url = https://t.co/D7zLml2b2D

# %% [markdown]
# #### Query 5

# %%
print("\033[1mInsert a query:\033[0m\n")
query = q[4]
ranked_tweets, scores = search_Word2Vec(query, index, X, X_tweets, pos_ids, ids_pos, model)    
top = 20

print("\n======================\n\033[1mTop {} results out of {} for the seached query:\033[0m\n".format(top, len(ranked_tweets)))
for d_id in ranked_tweets[:top] :
    print("\n\033[1mTweet id = {}\033[0m".format(d_id))
    print("   - Tweet_text = {} ".format(data[d_id]['org_text']))
    print("   - Tweet_user = {} ".format(data[d_id]['user']))
    print("   - Tweet_date = {} ".format(data[d_id]['date']))
    print("   - Tweet_hashtags = {} ".format(data[d_id]['hashtags']))
    print("   - Tweet_likes = {} ".format(data[d_id]['favorites']))
    print("   - Tweet_retweets = {} ".format(data[d_id]['retweets']))
    print("   - Tweet_url = {} ".format(data[d_id]['url']))
# Out:
# Insert a query:
#
#
# ======================
# Top 20 results out of 18 for the seached query:
#
#
# Tweet id = 1100
#    - Tweet_text = #Hypertension - or elevated blood pressure - is a serious medical condition that significantly increases the risks of ❤, 🧠, kidney &amp; other diseases.
#
# It is a major cause of premature death worldwide.
#
# 👉 https://t.co/PEXOASL1Tg https://t.co/QIAIsudIxE
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Wed Aug 25 12:38:53 +0000 2021
#    - Tweet_hashtags = ['Hypertension']
#    - Tweet_likes = 145
#    - Tweet_retweets = 70
#    - Tweet_url = https://t.co/QIAIsudIxE
#
# Tweet id = 323
#    - Tweet_text = Today is #WorldHeartDay 💗
#
# #Hypertension - or elevated blood pressure - is a serious medical condition that significantly increases the risks of ❤, 🧠, kidney &amp; other diseases. It is a major cause of premature death worldwide.
#
# 👉 https://t.co/PEXOASL1Tg https://t.co/L6vriEK1yc
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Wed Sep 29 08:25:28 +0000 2021
#    - Tweet_hashtags = ['WorldHeartDay', 'Hypertension']
#    - Tweet_likes = 229
#    - Tweet_retweets = 107
#    - Tweet_url = https://t.co/L6vriEK1yc
#
# Tweet id = 696
#    - Tweet_text = According to the WHO/@ILO Joint Estimates, the risk factors at work which cause the most deaths annually are
#
# 🕥 long working hours
# 🏭 air pollution, gases &amp; fumes
# 🤕 injuries.
#
# More in detail 👉https://t.co/mEXoBqYt5g #WorkersHealth https://t.co/WFXTglLppp
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Fri Sep 17 14:29:01 +0000 2021
#    - Tweet_hashtags = ['WorkersHealth']
#    - Tweet_likes = 132
#    - Tweet_retweets = 57
#    - Tweet_url = https://t.co/WFXTglLppp
#
# Tweet id = 541
#    - Tweet_text = #Breastfeeding 🤱 is a critical first #FoodSystem that ensures nutrition, health &amp; development of 👶.
#
# It's sustainable, not for profit &amp; it helps reduce:
# 📉preventable deaths
# 📉the risk of noncommunicable diseases
# 📉the risk of overweight/obesity
#
# 👉https://t.co/0MM8lIxZAx https://t.co/lphfIbfaYt
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Thu Sep 23 15:52:59 +0000 2021
#    - Tweet_hashtags = ['Breastfeeding', 'FoodSystem']
#    - Tweet_likes = 139
#    - Tweet_retweets = 52
#    - Tweet_url = https://t.co/lphfIbfaYt
#
# Tweet id = 1718
#    - Tweet_text = Hep B birthdose for babies can't wait:
# The vaccine protects your 👶 from this potentially life-threatening liver infection that can cause both acute &amp; chronic disease. #Hepatitis B can put people at high risk of death ☠️ from liver damage &amp; liver cancer
#
# 👉https://t.co/Em4LYylVms https://t.co/GVXr0WtdOw
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Wed Jul 28 12:13:41 +0000 2021
#    - Tweet_hashtags = ['Hepatitis']
#    - Tweet_likes = 161
#    - Tweet_retweets = 64
#    - Tweet_url = https://t.co/GVXr0WtdOw
#
# Tweet id = 1074
#    - Tweet_text = "Cardiovascular diseases are the leading cause of death globally, and #hypertension is one of its main risk factors.
# More than 1.2 billion people live with hypertension."-@DrTedros
# https://t.co/zHeYfeQEFv
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Wed Aug 25 15:49:12 +0000 2021
#    - Tweet_hashtags = ['hypertension']
#    - Tweet_likes = 43
#    - Tweet_retweets = 21
#    - Tweet_url =
#
# Tweet id = 793
#    - Tweet_text = Patients who are critically ill with severe #COVID19 are at higher risk of developing and dying from #sepsis
#
# If #sepsis is not recognized early and managed promptly, it can lead to septic shock, multiple organ failure &amp; death
#
# https://t.co/sSLSPAQFv8 https://t.co/PI0zUFL7um
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Mon Sep 13 09:48:20 +0000 2021
#    - Tweet_hashtags = ['COVID19', 'sepsis', 'sepsis']
#    - Tweet_likes = 264
#    - Tweet_retweets = 120
#    - Tweet_url = https://t.co/PI0zUFL7um
#
# Tweet id = 1875
#    - Tweet_text = The death of a parent or caregiver can have immediate &amp; lifelong harmful consequences for children incl. increased risks of:
# 🔸physical, emotional &amp; sexual violence
# 🔸#MentalHealth problems
# 🔸family poverty
#
# 👉https://t.co/2Gbl49N7pH https://t.co/R7t5f1Bp2C
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Wed Jul 21 08:10:31 +0000 2021
#    - Tweet_hashtags = ['MentalHealth']
#    - Tweet_likes = 189
#    - Tweet_retweets = 63
#    - Tweet_url = https://t.co/R7t5f1Bp2C
#
# Tweet id = 1386
#    - Tweet_text = These therapies - artesunate, imatinib and infliximab – were selected by an independent expert panel for their potential in reducing the risk of death in hospitalized #COVID19 patients. https://t.co/K6tk22NnFf
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Wed Aug 11 20:31:17 +0000 2021
#    - Tweet_hashtags = ['COVID19']
#    - Tweet_likes = 57
#    - Tweet_retweets = 21
#    - Tweet_url =
#
# Tweet id = 508
#    - Tweet_text = New data from over 90 countries highlights that the progress made in the fight against #tuberculosis is at risk with #COVID19 disruptions leading to 1.4 million additional people missing out on access to TB care in 2020 alone &amp; over half a million deaths. https://t.co/2CFqV8NQek
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Fri Sep 24 17:40:38 +0000 2021
#    - Tweet_hashtags = ['tuberculosis', 'COVID19']
#    - Tweet_likes = 48
#    - Tweet_retweets = 17
#    - Tweet_url =
#
# Tweet id = 2380
#    - Tweet_text = @DrTedros "As some countries ease public health and social measures, we are starting to see increases in #COVID19 transmission around the world. More cases means more hospitalizations, further stretching health workers and health systems, which increases the risk of death"-@DrTedros
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Fri Jun 25 15:33:14 +0000 2021
#    - Tweet_hashtags = ['COVID19']
#    - Tweet_likes = 69
#    - Tweet_retweets = 33
#    - Tweet_url =
#
# Tweet id = 2289
#    - Tweet_text = 8 of the 41 SIDS face pressing health workforce challenges related to #HealthForAll.
#
# #COVID19 has heavily impacted the health workers – including their heightened risk of infection &amp; death, burnout, fatigue, discrimination &amp; mental health issues. https://t.co/xGEJBModDa
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Tue Jun 29 13:53:43 +0000 2021
#    - Tweet_hashtags = ['HealthForAll', 'COVID19']
#    - Tweet_likes = 28
#    - Tweet_retweets = 11
#    - Tweet_url =
#
# Tweet id = 2108
#    - Tweet_text = @DrTedros @G20 "This followed a comprehensive new analysis of 27 randomised trials involving nearly 11,000 patients, which found that treating hospitalised #COVID19 patients with IL-6 receptor blockers reduces the risk of death and the need for mechanical ventilation"-@DrTedros
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Wed Jul 07 13:30:22 +0000 2021
#    - Tweet_hashtags = ['COVID19']
#    - Tweet_likes = 48
#    - Tweet_retweets = 26
#    - Tweet_url =
#
# Tweet id = 753
#    - Tweet_text = @DrTedros "More than 5.7B [#COVID19 vaccine] doses have been administered globally, but only 2% of those have been administered in Africa. This leaves people at high risk of disease &amp; death exposed to a deadly virus against which many other people around the 🌍 enjoy protection"-@DrTedros
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Tue Sep 14 14:12:04 +0000 2021
#    - Tweet_hashtags = ['COVID19']
#    - Tweet_likes = 92
#    - Tweet_retweets = 45
#    - Tweet_url =
#
# Tweet id = 97
#    - Tweet_text = It's #WorldMentalHealthDay.
#
# DYK: 1️⃣ in 1️⃣0️⃣0️⃣ deaths is by #suicide. For every suicide there are many more people who attempt suicide. A prior suicide attempt is an important risk factor.
# #LetsTalk https://t.co/cugMvd8oHu
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Sun Oct 10 08:21:24 +0000 2021
#    - Tweet_hashtags = ['WorldMentalHealthDay', 'suicide', 'LetsTalk']
#    - Tweet_likes = 298
#    - Tweet_retweets = 142
#    - Tweet_url = https://t.co/cugMvd8oHu
#
# Tweet id = 1523
#    - Tweet_text = Here is what we know about heart inflammation (myocarditis or pericarditis) and mRNA vaccines 👇
#
# The benefits of these vaccines 💉 greatly outweigh the risk of myocarditis &amp; pericarditis by preventing deaths &amp; hospitalisations due to #COVID19.
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Wed Aug 04 10:49:48 +0000 2021
#    - Tweet_hashtags = ['COVID19']
#    - Tweet_likes = 233
#    - Tweet_retweets = 101
#    - Tweet_url =
#
# Tweet id = 969
#    - Tweet_text = @DrTedros "3rd dose may be necessary for at most risk ppl, where there's evidence of waning immunity against severe #COVID19 disease &amp; death – such as the small group of immunocompromised ppl who didn't respond sufficiently to initial doses, or are no longer producing antibodies"-@DrTedros
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Wed Sep 01 15:13:26 +0000 2021
#    - Tweet_hashtags = ['COVID19']
#    - Tweet_likes = 72
#    - Tweet_retweets = 35
#    - Tweet_url =
#
# Tweet id = 844
#    - Tweet_text = @DrTedros "3rd doses may be necessary for the most at-risk populations, where there's evidence of waning immunity against severe #COVID19 &amp; death – such as immunocompromised people who didn't respond sufficiently to their initial doses, or are no longer producing antibodies"-@DrTedros
#    - Tweet_user = World Health Organization (WHO)
#    - Tweet_date = Wed Sep 08 14:48:16 +0000 2021
#    - Tweet_hashtags = ['COVID19']
#    - Tweet_likes = 92
#    - Tweet_retweets = 39
#    - Tweet_url =
